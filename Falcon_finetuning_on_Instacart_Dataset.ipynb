# %% [markdown]
# ## Installing Necessary Libraries

# %%
# !pip install -q -U trl transformers accelerate git+https://github.com/huggingface/peft.git
# !pip install -q datasets bitsandbytes einops wandb
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 18.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 27.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 46.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 51.5 MB/s eta 0:00:00
#   Building wheel for peft (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 94.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 22.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.7/214.7 kB 23.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.6 MB/s eta 0:00:00
#   Building wheel for pathtools (setup.py) ... done

# %% [markdown]
# # Dataset details
# Instacart Data can be downloaded from [here](https://www.kaggle.com/competitions/instacart-market-basket-analysis/data). We just need product & department csv files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/'Colab Notebooks'
# Out:
# departments.csv  products.csv

# %%
import pandas as pd
df_product = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/products.csv")
df_dept = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/departments.csv')

# %%
df_joined = pd.merge(df_product, df_dept, on = ['department_id'])
df_joined['text'] = df_joined.apply(lambda row: row['product_name'] + " ->: " + row['department'], axis = 1)

# %%
from sklearn.model_selection import train_test_split
train_df, test_df = train_test_split(df_joined, test_size=0.2, random_state=42)

# %%
train_df.head(10)
# Out:
#        product_id                                       product_name  \
# 7361        10376                              Organic Caraway Seeds
# 32534       40131                         Original Laundry Detergent
# 1457        11913                                 Shelled Pistachios
# 5201        41392                   Harvest Berry Chewy Granola Bars
# 38539       28627              Veganic Sprouted Red Fife Raisin Bran
# 18377       29407                               Root Vegetable Cakes
# 28627       29571                                  Alta Dena 1% Milk
# 30283        3589                             Laundry Detergent Pods
# 32030       31685  Daily Shower Cleaner Scrub Free Refill, Fresh ...
# 28655       30119            Organic French Style Meyer Lemon Yogurt
#
#        aisle_id  department_id  department  \
# 7361        104             13      pantry
# 32534        75             17   household
# 1457        117             19      snacks
# 5201          3             19      snacks
# 38539       121             14   breakfast
# 18377        42              1      frozen
# 28627        84             16  dairy eggs
# 30283        75             17   household
# 32030       114             17   household
# 28655       120             16  dairy eggs
#
#                                                     text
# 7361                    Organic Caraway Seeds ->: pantry
# 32534           Original Laundry Detergent ->: household
# 1457                       Shelled Pistachios ->: snacks
# 5201         Harvest Berry Chewy Granola Bars ->: snacks
# 38539  Veganic Sprouted Red Fife Raisin Bran ->: brea...
# 18377                    Root Vegetable Cakes ->: frozen
# 28627                   Alta Dena 1% Milk ->: dairy eggs
# 30283               Laundry Detergent Pods ->: household
# 32030  Daily Shower Cleaner Scrub Free Refill, Fresh ...
# 28655  Organic French Style Meyer Lemon Yogurt ->: da...

# %%
test_df.head(10)
# Out:
#        product_id                                       product_name  \
# 33626       24154             Free & Clear Stage 4 Overnight Diapers
# 18192       27348  Beef pot roast with roasted potatoes, carrots,...
# 47099       27181                                      Coffee Liquer
# 48183       20577                                        Bread Rolls
# 22197       16472           French Milled Oval Almond Gourmande Soap
# 31573       24121                                           Dust Pan
# 45362        5477                            Roasted Pine Nut Hommus
# 14131       27921                 Cranberry Raspberry Juice Cocktail
# 26903        4786                          Sweet Cream Butter Salted
# 39417        8796                    Traditional Chicken Barley Soup
#
#        aisle_id  department_id     department  \
# 33626        56             18         babies
# 18192        38              1         frozen
# 47099       124              5        alcohol
# 48183        43              3         bakery
# 22197        25             11  personal care
# 31573       114             17      household
# 45362        67             20           deli
# 14131        98              7      beverages
# 26903        36             16     dairy eggs
# 39417        69             15   canned goods
#
#                                                     text
# 33626  Free & Clear Stage 4 Overnight Diapers ->: babies
# 18192  Beef pot roast with roasted potatoes, carrots,...
# 47099                          Coffee Liquer ->: alcohol
# 48183                             Bread Rolls ->: bakery
# 22197  French Milled Oval Almond Gourmande Soap ->: p...
# 31573                             Dust Pan ->: household
# 45362                   Roasted Pine Nut Hommus ->: deli
# 14131   Cranberry Raspberry Juice Cocktail ->: beverages
# 26903           Sweet Cream Butter Salted ->: dairy eggs
# 39417   Traditional Chicken Barley Soup ->: canned goods

# %%
from datasets import Dataset,DatasetDict
train_dataset_dict = DatasetDict({
    "train": Dataset.from_pandas(train_df),
})

# %%
train_dataset_dict
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['product_id', 'product_name', 'aisle_id', 'department_id', 'department', 'text', '__index_level_0__'],
#         num_rows: 39750
#     })
# })

# %% [markdown]
# ## Loading the model

# %% [markdown]
# In this section we will load the [Falcon 7B model](https://huggingface.co/tiiuae/falcon-7b), quantize it in 4bit and attach LoRA adapters on it. Let's get started!

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, AutoTokenizer

model_name = "ybelkada/falcon-7b-sharded-bf16"
# model_name = "tiiuae/falcon-7b"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    trust_remote_code=True
)
model.config.use_cache = False
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.10k [00:00<?, ?B/s]
# Downloading (…)/configuration_RW.py:   0%|          | 0.00/2.61k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/tiiuae/falcon-7b:
# - configuration_RW.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# Downloading (…)main/modelling_RW.py:   0%|          | 0.00/47.6k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/tiiuae/falcon-7b:
# - modelling_RW.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# Downloading (…)model.bin.index.json:   0%|          | 0.00/16.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/8 [00:00<?, ?it/s]
# Downloading (…)l-00001-of-00008.bin:   0%|          | 0.00/1.92G [00:00<?, ?B/s]
# Downloading (…)l-00002-of-00008.bin:   0%|          | 0.00/1.99G [00:00<?, ?B/s]
# Downloading (…)l-00003-of-00008.bin:   0%|          | 0.00/1.91G [00:00<?, ?B/s]
# Downloading (…)l-00004-of-00008.bin:   0%|          | 0.00/1.91G [00:00<?, ?B/s]
# Downloading (…)l-00005-of-00008.bin:   0%|          | 0.00/1.99G [00:00<?, ?B/s]
# Downloading (…)l-00006-of-00008.bin:   0%|          | 0.00/1.91G [00:00<?, ?B/s]
# Downloading (…)l-00007-of-00008.bin:   0%|          | 0.00/1.91G [00:00<?, ?B/s]
# Downloading (…)l-00008-of-00008.bin:   0%|          | 0.00/921M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]

# %% [markdown]
# Let's also load the tokenizer below

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/180 [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.73M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/281 [00:00<?, ?B/s]

# %% [markdown]
# **Let's check what the base model predicts before finetuning. :)**

# %%
import transformers
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="auto",
)


sequences = pipeline(
   ["“Free & Clear Stage 4 Overnight Diapers” ->:","Bread Rolls ->:","French Milled Oval Almond Gourmande Soap ->:"],
    max_length=200,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
for seq in sequences:
    print(f"Result: {seq[0]['generated_text']}")
# Out:
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1270: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation )
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Result: “Free & Clear Stage 4 Overnight Diapers” ->: $9.99
# - “Bamboo & O’s Free & Clear Overnight Diapers” -> $14.99
# - “Bamboo & O’s Free & Clear Stage 2 Overnight Diaper” -> $10.99
# - “Bamboo & O’s Free & Clear Stage 3 Overnight Diapers” -> $13.99
# - “O’s Free & Clear Overnight Diapers” -> $14.99
# Result: Bread Rolls ->:
# - 2 cups Bread crumbs
# - 3 tbsp Butter
# - 3 tbsp Garlic Paste
# - 3 tbsp Onion paste
# - 3 tbsp Chopped Green chillies
# - 2 tsp Chilli powder
# - 1-1/2 tsp Coriander powder (powdered)
# - 1/2 tsp Cumin powder
# - 1/2 tsp Turmeric powder
# - 1 tsp Lemon juice (fresh)
# - Salt to taste
# - Oil for frying
# How to make Bread Rolls
# - Combine bread crumbs, melted butter, green chilli and salt in a bowl and knead well.
# - Make 12 small balls. Flatten these balls.
# - Fill with chopped green chillies, onions, garlic, coriander, cumin and turmeric.
# - Shape into round rolls and seal with bread crumbs. Repeat this process until all is done.
# - Deep fry these rolls till golden in color.
#
# Result: French Milled Oval Almond Gourmande Soap ->: $9.00
# Price: $9.00
# This is a wonderful almond fragranced soap with a light almond scent. The soap is made with French Milled soap base to make it very gentle to the skin. This is a great choice for people with dry or sensitive skin.
# There are no reviews for this product.
# Be a hero. Here’s how:

# %% [markdown]
# Below we will load the configuration file in order to create the LoRA model. According to QLoRA paper, it is important to consider all linear layers in the transformer block for maximum performance. Therefore we will add `dense`, `dense_h_to_4_h` and `dense_4h_to_h` layers in the target modules in addition to the mixed query key value layer.

# %%
from peft import LoraConfig

lora_alpha = 16
lora_dropout = 0.1
lora_r = 64

peft_config = LoraConfig(
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    r=lora_r,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=[
        "query_key_value",
        "dense",
        "dense_h_to_4h",
        "dense_4h_to_h",
    ]
)

# %% [markdown]
# ## Loading the trainer

# %% [markdown]
# Here we will use the [`SFTTrainer` from TRL library](https://huggingface.co/docs/trl/main/en/sft_trainer) that gives a wrapper around transformers `Trainer` to easily fine-tune models on instruction based datasets using PEFT adapters. Let's first load the training arguments below.

# %%
from transformers import TrainingArguments

output_dir = "./results"
per_device_train_batch_size = 4
gradient_accumulation_steps = 4
optim = "paged_adamw_32bit"
save_steps = 10
logging_steps = 1
learning_rate = 2e-4
max_grad_norm = 0.3
max_steps = 120 #500
warmup_ratio = 0.03
lr_scheduler_type = "constant"

training_arguments = TrainingArguments(
    output_dir=output_dir,
    per_device_train_batch_size=per_device_train_batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,
    optim=optim,
    save_steps=save_steps,
    logging_steps=logging_steps,
    learning_rate=learning_rate,
    fp16=True,
    max_grad_norm=max_grad_norm,
    max_steps=max_steps,
    warmup_ratio=warmup_ratio,
    group_by_length=True,
    lr_scheduler_type=lr_scheduler_type,
)

# %% [markdown]
# Then finally pass everthing to the trainer

# %%
from trl import SFTTrainer

max_seq_length = 512

trainer = SFTTrainer(
    model=model,
    train_dataset=train_dataset_dict['train'],
    # train_dataset=data['train'],
    peft_config=peft_config,
    dataset_text_field="text",
    # dataset_text_field="prediction",
    max_seq_length=max_seq_length,
    tokenizer=tokenizer,
    args=training_arguments,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:102: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(
# Map:   0%|          | 0/39750 [00:00<?, ? examples/s]

# %% [markdown]
# We will also pre-process the model by upcasting the layer norms in float 32 for more stable training

# %%
for name, module in trainer.model.named_modules():
    if "norm" in name:
        module = module.to(torch.float32)

# %% [markdown]
# ## Train the model

# %% [markdown]
# Now let's train the model! Simply call `trainer.train()`

# %%
trainer.train()
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.15.5
# Run data is saved locally in <code>/content/wandb/run-20230723_130659-3tvldijj</code>
# Syncing run <strong><a href='https://wandb.ai/imsamread81/huggingface/runs/3tvldijj' target="_blank">woven-thunder-33</a></strong> to <a href='https://wandb.ai/imsamread81/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/imsamread81/huggingface' target="_blank">https://wandb.ai/imsamread81/huggingface</a>
#  View run at <a href='https://wandb.ai/imsamread81/huggingface/runs/3tvldijj' target="_blank">https://wandb.ai/imsamread81/huggingface/runs/3tvldijj</a>
# You're using a PreTrainedTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='120' max='120' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [120/120 16:13, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.938300</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.296200</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>4.448400</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>4.121700</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.952100</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.435200</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.537000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.795100</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.374100</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>2.365600</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>3.058100</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>2.554300</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>2.634900</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>2.235100</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>2.425200</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>2.148800</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>2.609000</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>2.109000</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>2.410400</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>2.028700</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>2.335400</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>2.242700</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.976800</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>2.178500</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.951900</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>2.046900</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>2.130100</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.788800</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>2.272700</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.883400</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>1.927200</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>1.964300</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.983900</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>2.286900</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>2.497800</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>2.208000</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>1.818600</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>1.904200</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>2.228600</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>2.110700</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>1.931900</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>2.199700</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>2.056100</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>1.863600</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>1.789100</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>1.864800</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>1.972300</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>1.637900</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>1.699000</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.652300</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>4.087000</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>3.813300</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>3.258500</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>2.877400</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>2.421900</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>2.370900</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>2.912000</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>2.114300</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>2.203900</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>2.209700</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>2.289300</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>2.392700</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>2.084100</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>1.973800</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>2.143200</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>1.852700</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>2.291100</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>2.106400</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>2.297900</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.797700</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>2.274300</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>2.044900</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>2.312900</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>2.250300</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>1.975400</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>2.311600</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>2.147200</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>1.898400</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>2.127700</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>2.119800</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>1.721200</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>2.049900</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>1.647800</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>2.096000</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>1.984600</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>1.981200</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>2.190800</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>1.925900</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>1.792400</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>1.998400</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>2.067900</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>1.562400</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>1.676100</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>1.993800</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>1.845800</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>1.777800</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>1.633600</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>1.573500</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>1.782300</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.793800</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>3.037600</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>2.975800</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>2.854500</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>2.548800</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>2.370300</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>2.126800</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>2.206500</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>1.959800</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>1.660000</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>2.259200</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>2.024400</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>2.055400</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>2.134400</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>1.954800</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>2.346500</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>1.734200</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>2.190800</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>2.132700</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>2.072000</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>1.880200</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=120, training_loss=2.2621813853581747, metrics={'train_runtime': 994.1988, 'train_samples_per_second': 1.931, 'train_steps_per_second': 0.121, 'total_flos': 479793488348160.0, 'train_loss': 2.2621813853581747, 'epoch': 0.05})

# %%
lst_test_data = list(test_df['text'])

# %%
len(lst_test_data)
# Out:
# 9938

# %%
sample_size = 25
lst_test_data_short = lst_test_data[:sample_size]

# %%
import transformers

pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    # torch_dtype=torch.bfloat16,
    torch_dtype=torch.float16,
    trust_remote_code=True,
    device_map="auto",
)

sequences = pipeline(
    lst_test_data_short,
    max_length=100,  #200,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)

for ix,seq in enumerate(sequences):
    print(ix,seq[0]['generated_text'])
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py
#  'household pets pets other pets other pets pets: household pets pets other pets other pets pets: household pets pets other pets other pets pets: household pets pets other pets other pets pets: household pets pets other pets other pets pets: household pets pets other pets other pets pets: household pets pets other pets other pets pets: household pets pets other pets other pets pets: household pets pets other pets other pets pets: household pets pets other pets other pets pets: household pets pets',
#  'frozen seafood pasta rice dry pasta',
#  'dairy eggs eggs-dairy eggs-eggs eggs-gluten-free eggs eggs-soy eggs-white soy-milk other dairy soy milk unsweetened soy',
#  'breakfast dry goods pasta rice baby',
#  'personal care personal care other personal care personal care personal care personal care personal care personal care personal care household household personal care personal care household',
#  'meat seafood seafood fish canned salmon']

# %%
df_evaluate = test_df.iloc[:sample_size][['product_name','department']]

df_evaluate = df_evaluate.reset_index(drop=True)

df_evaluate['department_predicted'] = answers

df_evaluate
# Out:
#                                          product_name       department  \
# 0              Free & Clear Stage 4 Overnight Diapers           babies
# 1   Beef pot roast with roasted potatoes, carrots,...           frozen
# 2                                       Coffee Liquer          alcohol
# 3                                         Bread Rolls           bakery
# 4            French Milled Oval Almond Gourmande Soap    personal care
# 5                                            Dust Pan        household
# 6                             Roasted Pine Nut Hommus             deli
# 7                  Cranberry Raspberry Juice Cocktail        beverages
# 8                           Sweet Cream Butter Salted       dairy eggs
# 9                     Traditional Chicken Barley Soup     canned goods
# 10                     Vanilla Unsweetened Cashewmilk       dairy eggs
# 11        Minis Size Chocolate Candy Bars Variety Mix           snacks
# 12                  Cheesy Cheddar Rotini Pasta Sides  dry goods pasta
# 13                             Multi Purpose Solution    personal care
# 14                  Juice, Raw & Cold-Pressed, Purity        beverages
# 15                         Chinese Five Spices Powder    international
# 16                     Ancient Grain Original Granola        breakfast
# 17  Crunch Lemon Shortbread Flavor 0% Fat with Top...       dairy eggs
# 18                                   Flounder Fillets     meat seafood
# 19                                       Lilac Votive        household
# 20                 Cheese & Broccoli Ravioli For Kids           frozen
# 21                Organic Soymilk Original Value Size       dairy eggs
# 22           Fruit Juice Sweetened Millet Rice Cereal        breakfast
# 23              Morning Burst® Facial Scrub Cleansers    personal care
# 24                                   Salmon Pinwheels     meat seafood
#
#                                  department_predicted
# 0   babies personal care household products babies...
# 1   frozen meat seafood meat seafood canned goods ...
# 2   alcohol beverages alcohol fortified wine alcoh...
# 3   bakery deli pasta seafood frozen seafood inter...
# 4   personal care personal care soap and body wash...
# 5              household supplies dry goods household
# 6   deli dry goods pasta beans canned goods canned...
# 7   beverages international other missing ingredie...
# 8   dairy eggs fish meat seafood shellfish tree nu...
# 9   canned goods dry goods pasta rice beans canned...
# 10  dairy eggs gluten meat seafood shellfish soy o...
# 11              snacks international other chocolates
# 12          dry goods pasta rice and grains pasta dry
# 13  personal care personal care personal care pers...
# 14  beverages eggs fish seafood produce other food...
# 15  international foods dry goods pasta & dry good...
# 16  breakfast dry goods pasta dry goods pasta dry ...
# 17  dairy eggs eggs free ice cream snacks sweets y...
# 18                    meat seafood seafood fish fresh
# 19  household pets pets other pets other pets pets...
# 20                frozen seafood pasta rice dry pasta
# 21  dairy eggs eggs-dairy eggs-eggs eggs-gluten-fr...
# 22                breakfast dry goods pasta rice baby
# 23  personal care personal care other personal car...
# 24            meat seafood seafood fish canned salmon
